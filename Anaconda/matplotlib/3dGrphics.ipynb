# %%
import matplotlib        as mlt
import matplotlib.pyplot as plt
import numpy             as np

# %% [markdown]
# # **Graphiques en 3D**

# %% [markdown]
# ### **Les nuages de points**

# %%
x = np.random.normal(0,1,100) # moyenne, écart type, nombre de valeurs
y = np.random.normal(0,1,100)
z = np.random.normal(0,1,100)

# %%
# la rendre deplaçable `%matplotlib`
# %matplotlib
plt.figure(figsize=(10,8))
ax = plt.axes(projection = '3d')
ax.scatter3D(x,y,z, s=40) # s=taille dees points

# placer les axes
ax.set_xlabel('axe x')
ax.set_ylabel('axe y')
ax.set_zlabel('axe z')
# Out:
# Using matplotlib backend: module://matplotlib_inline.backend_inline
# Text(0.5, 0, 'axe z')

# %% [markdown]
# ### **Courbe en 3D**

# %%
val_x = np.linspace(0,20,200) # 200 éléments entre 0 et 20
val_y = np.cos(2*val_x)
val_z = np.sin(2*val_x)

plt.figure(figsize=(10,8))
ax1 = plt.axes(projection = '3d')
ax1.plot3D(val_x,val_y,val_z, lw=5, color='#FF6D2D') # épaisseur de la linge orange 5
